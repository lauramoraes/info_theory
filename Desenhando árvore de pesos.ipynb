# %%
import matplotlib.pyplot as plt
import networkx as nx
from networkx.drawing.nx_agraph import graphviz_layout

# %matplotlib inline

# %%
#G = nx.Graph()
G = nx.DiGraph()

pesados = list(range(1,40))
leves = [-1*element for element in range(1,40)]

# Adicionando nós
labels = {}
# Primeiro nivel
labels[1] = "1:13 x 14:26"
labels[2] = "(1:5 + 14:17) x (6:10 + 18:21)"
labels[3] = "(1:5 + 14:17) x (6:10 + 18:21)"
labels[4] = "27:31 x 32:35"

# Segundo nível
labels[5] = "1,2,18 x 3,4,19"
labels[6] = "6,7,14 x 8,9,15"
labels[7] = "11,22,23 x 12,24,25"
labels[8] = "6,7,14 x 8,9,15"
labels[9] = "1,2,18 x 3,4,19"
labels[10] = "11,22,23 x 12,24,25"
labels[11] = "27,28,32 x 29,30,33"
labels[12] = "27,28,32 x 29,30,33"
labels[13] = "36,37" x "38, Coringa"

# Terceiro nível
labels[14] = "1 x 2"
labels[15] = "3 x 4"
labels[16] = "20 x 21"
labels[17] = "6 x 7"
labels[18] = "8 x 9"
labels[19] = "16 x 17"
labels[20] = "24 x 25"
labels[21] = "22 x 23"
labels[22] = "13 x Coringa"
labels[23] = "8 x 9"
labels[24] = "6 x 7"
labels[25] = "16 x 17"
labels[26] = "3 x 4"
labels[27] = "1 x 2"
labels[28] = "20 x 21"
labels[29] = "22 x 23"
labels[30] = "24 x 25"
labels[31] = "13 x Coringa"



# Pesagens do primeiro nível
G.add_edge(1, 2, weight=1, available="+1 a +13; -14 a -26")
G.add_edge(1, 3, weight=1, available="-1 a -13; +14 a +26")
G.add_edge(1, 4, weight=1, available="+27 a +39; -27 a -39")

# Pesagens do segundo nível, parte 1
G.add_edge(2, 5, weight=1, available="+1 a +5; -18 a -21")
G.add_edge(2, 6, weight=1, available="+6 a +10; -14 a -17")
G.add_edge(2, 7, weight=1, available="+11 a +13; -22 a -26")

# Pesagens do segundo nível, parte 2
G.add_edge(3, 8, weight=1, available="-6 a -10; +14 a +17")
G.add_edge(3, 9, weight=1, available="-1 a -5; +18 a +21")
G.add_edge(3, 10, weight=1, available="-11 a -13; +22 a +26")

# Pesagens do segundo nível, parte 3
G.add_edge(4, 11, weight=1, available="+27 a +31; -32 a -35")
G.add_edge(4, 12, weight=1, available="-27 a -31; +32 a +35")
G.add_edge(4, 13, weight=1, available="-36 a -39; +36 a +39")

# Pesagens do terceiro nível, parte 1.1
G.add_edge(5, 14, weight=1, available="+1, +2, -19")
G.add_edge(5, 15, weight=1, available="+3, +4, -18")
G.add_edge(5, 16, weight=1, available="+5, -20, -21")

# Pesagens do terceiro nível, parte 1.2
G.add_edge(6, 17, weight=1, available="+6, +7, -15")
G.add_edge(6, 18, weight=1, available="+8, +9, -14")
G.add_edge(6, 19, weight=1, available="+10, -16, -17")

# Pesagens do terceiro nível, parte 1.3
G.add_edge(7, 20, weight=1, available="+11, -24, -25")
G.add_edge(7, 21, weight=1, available="+12, -22, -23")
G.add_edge(7, 22, weight=1, available="+13, -26")

# Pesagens do terceiro nível, parte 2.1
G.add_edge(8, 23, weight=1, available="-8, -9, +14")
G.add_edge(8, 24, weight=1, available="-6, -7, +15")
G.add_edge(8, 25, weight=1, available="-10, +16, +17")

# Pesagens do terceiro nível, parte 2.2
G.add_edge(9, 26, weight=1, available="-3, -4, +18")
G.add_edge(9, 27, weight=1, available="-1, -2, +19")
G.add_edge(9, 28, weight=1, available="-5, +20, +21")

# Pesagens do terceiro nível, parte 2.3
G.add_edge(10, 29, weight=1, available="-12, +22, +23")
G.add_edge(10, 30, weight=1, available="-11, +24, +25")
G.add_edge(10, 31, weight=1, available="-13, +26")

# Pesagens do terceiro nível, parte 3.1
G.add_edge(11, 32, weight=1, available="+27, +28, -33")
G.add_edge(11, 33, weight=1, available="+29, +30, -32")
G.add_edge(11, 34, weight=1, available="+31, -34, -35")

# Pesagens do terceiro nível, parte 3.2
G.add_edge(12, 35, weight=1, available="-29, -30, +32")
G.add_edge(12, 36, weight=1, available="-27, -28, +33")
G.add_edge(12, 37, weight=1, available="-31, +34, +35")

# Pesagens do terceiro nível, parte 3.3
G.add_edge(13, 38, weight=1, available="+36, +37, -38")
G.add_edge(13, 39, weight=1, available="-36, -37, +38")
G.add_edge(13, 40, weight=1, available="-39, +39")

# Pesagens do quarto nível, parte 1.1.1
G.add_edge(14, 41, weight=1, available="+1")
G.add_edge(14, 42, weight=1, available="+2")
G.add_edge(14, 43, weight=1, available="-19")

# Pesagens do quarto nível, parte 1.1.2
G.add_edge(15, 44, weight=1, available="+3")
G.add_edge(15, 45, weight=1, available="+4")
G.add_edge(15, 46, weight=1, available="-18")

# Pesagens do quarto nível, parte 1.1.3
G.add_edge(5, 47, weight=1, available="-21")
G.add_edge(5, 48, weight=1, available="-20")
G.add_edge(5, 49, weight=1, available="+5")

# Pesagens do quarto nível, parte 1.2.1
G.add_edge(17, 50, weight=1, available="+6")
G.add_edge(17, 51, weight=1, available="+7")
G.add_edge(17, 52, weight=1, available="-15")

# Pesagens do quarto nível, parte 1.2.2
G.add_edge(18, 53, weight=1, available="+8")
G.add_edge(18, 54, weight=1, available="+9")
G.add_edge(18, 55, weight=1, available="-14")

# Pesagens do quarto nível, parte 1.2.3
G.add_edge(19, 56, weight=1, available="-17")
G.add_edge(19, 57, weight=1, available="-16")
G.add_edge(19, 58, weight=1, available="+10")

# Pesagens do quarto nível, parte 1.3.1
G.add_edge(20, 59, weight=1, available="-25")
G.add_edge(20, 60, weight=1, available="-24")
G.add_edge(20, 61, weight=1, available="+11")

# Pesagens do quarto nível, parte 1.3.2
G.add_edge(21, 62, weight=1, available="-23")
G.add_edge(21, 63, weight=1, available="-22")
G.add_edge(21, 64, weight=1, available="+12")

# Pesagens do quarto nível, parte 1.3.3
G.add_edge(22, 65, weight=1, available="+13")
G.add_edge(22, 66, weight=1, available="*")
G.add_edge(22, 67, weight=1, available="-26")

# Pesagens do quarto nível, parte 2.1.1
G.add_edge(23, 68, weight=1, available="-9")
G.add_edge(23, 69, weight=1, available="-8")
G.add_edge(23, 70, weight=1, available="+14")

# Pesagens do quarto nível, parte 2.1.2
G.add_edge(24, 71, weight=1, available="-7")
G.add_edge(24, 72, weight=1, available="-6")
G.add_edge(24, 73, weight=1, available="+15")

# Pesagens do quarto nível, parte 2.1.3
G.add_edge(25, 74, weight=1, available="+16")
G.add_edge(25, 75, weight=1, available="+17")
G.add_edge(25, 76, weight=1, available="-10")

# Pesagens do quarto nível, parte 2.2.1
G.add_edge(26, 77, weight=1, available="-4")
G.add_edge(26, 78, weight=1, available="-3")
G.add_edge(26, 79, weight=1, available="+18")

# Pesagens do quarto nível, parte 2.2.2
G.add_edge(27, 80, weight=1, available="-2")
G.add_edge(27, 81, weight=1, available="-1")
G.add_edge(27, 82, weight=1, available="+19")

# Pesagens do quarto nível, parte 2.2.3
G.add_edge(28, 83, weight=1, available="+20")
G.add_edge(28, 84, weight=1, available="+21")
G.add_edge(28, 85, weight=1, available="-5")

# Pesagens do quarto nível, parte 2.3.1
G.add_edge(29, 86, weight=1, available="+22")
G.add_edge(29, 87, weight=1, available="+23")
G.add_edge(29, 88, weight=1, available="-12")

# Pesagens do quarto nível, parte 2.3.2
G.add_edge(30, 89, weight=1, available="+24")
G.add_edge(30, 90, weight=1, available="+25")
G.add_edge(30, 91, weight=1, available="-11")

# Pesagens do quarto nível, parte 2.3.3
G.add_edge(31, 92, weight=1, available="*")
G.add_edge(31, 93, weight=1, available="-13")
G.add_edge(31, 94, weight=1, available="+26")

# Pesagens do quarto nível, parte 3.1.1
G.add_edge(32, 95, weight=1, available="+27")
G.add_edge(32, 96, weight=1, available="+28")
G.add_edge(32, 97, weight=1, available="-33")

# Pesagens do quarto nível, parte 3.1.2
G.add_edge(33, 98, weight=1, available="+29")
G.add_edge(33, 99, weight=1, available="+30")
G.add_edge(33, 100, weight=1, available="-32")

# Pesagens do quarto nível, parte 3.1.3
G.add_edge(34, 101, weight=1, available="-35")
G.add_edge(34, 102, weight=1, available="-34")
G.add_edge(34, 103, weight=1, available="+31")

# Pesagens do quarto nível, parte 3.2.1
G.add_edge(35, 104, weight=1, available="-30")
G.add_edge(35, 105, weight=1, available="-29")
G.add_edge(35, 106, weight=1, available="+32")

# Pesagens do quarto nível, parte 3.2.2
G.add_edge(36, 107, weight=1, available="-28")
G.add_edge(36, 108, weight=1, available="-27")
G.add_edge(36, 109, weight=1, available="+33")

# Pesagens do quarto nível, parte 3.2.3
G.add_edge(37, 110, weight=1, available="+34")
G.add_edge(37, 111, weight=1, available="+35")
G.add_edge(37, 112, weight=1, available="-31")

# Pesagens do quarto nível, parte 3.3.1
G.add_edge(38, 113, weight=1, available="+36")
G.add_edge(38, 114, weight=1, available="+37")
G.add_edge(38, 115, weight=1, available="-38")

# Pesagens do quarto nível, parte 3.3.2
G.add_edge(39, 116, weight=1, available="-36")
G.add_edge(39, 117, weight=1, available="-37")
G.add_edge(39, 118, weight=1, available="+38")

# Pesagens do quarto nível, parte 3.3.3
G.add_edge(40, 119, weight=1, available="+39")
G.add_edge(40, 120, weight=1, available="-39")
G.add_edge(40, 121, weight=1, available="*")


#nx.write_dot(G,'test.dot')
pos=graphviz_layout(G, prog='dot')

# version 1
#plt.figure(1, figsize=(20,20))
#nx.draw(G,pos, with_labels=True)
# use default edge labels
#nx.draw_networkx_edge_labels(G,pos)

# version 2
plt.figure(2, figsize=(30,15))
nx.draw(G,pos)
# specifiy edge labels explicitly
edge_labels=dict([((u,v,),d['available'])
             for u,v,d in G.edges(data=True)])
nx.draw_networkx_edge_labels(G,pos,edge_labels=edge_labels)
nx.draw_networkx_labels(G,pos, labels=labels)

# show graphs
plt.axis('off')
plt.savefig("39_tree.png", bbox_inches="tight")
plt.show()
# Out:
# /home/lmoraes/miniconda3/envs/notebook3/lib/python3.5/site-packages/networkx/drawing/nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# /home/lmoraes/miniconda3/envs/notebook3/lib/python3.5/site-packages/networkx/drawing/nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# /home/lmoraes/miniconda3/envs/notebook3/lib/python3.5/site-packages/matplotlib/__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# ...
